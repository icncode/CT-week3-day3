# %% [markdown]
# # Python Requests

# %% [markdown]
# ## Tasks Today:
#
#
# 1) <b>Requests package</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) pip install <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) requests.get <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Response object <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .content and .text <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) JSON <br>
# 2) <b>Python Wrapper</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) API key and base url<br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Creating a class for our requests<br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Private method for getting the response data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Public method for displaying the data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) In-Class Exercise #1 - Add a method for getting the high and lows for the next 3 days <br>
# 3) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Pokemon Wrapper  <br>

# %% [markdown]
# ## PyPI - Python Package Inedex

# %% [markdown]
# The Python Package Index (PyPI) is a repository of software for the Python programming language. https://pypi.org/

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !pip --version
# Out:
# pip 22.2.2 from C:\ProgramData\Anaconda3\lib\site-packages\pip (python 3.9)

# %%
# !python -m pip install Faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from faker import Faker

fake = Faker()
print(fake)

# %%
fake.name()
# Out:
# 'Douglas Miranda'

# %%
fake_data = []

for _ in range(10):
    first = fake.first_name()
    last = fake.last_name()
    person_info = {
        'first_name': first,
        'last_name': last,
        'city': fake.city(),
        'email': f"{first.lower()}.{last.lower()}@{fake.free_email_domain()}",
        'occupation': {
            'company': fake.company(),
            'position':fake.job()
        }
    }
    fake_data.append(person_info)
    
fake_data
# Out:
# [{'first_name': 'Richard',
#   'last_name': 'Henderson',
#   'city': 'Brandonhaven',
#   'email': 'richard.henderson@gmail.com',
#   'occupation': {'company': 'Zimmerman, Smith and Hansen',
#    'position': 'Pharmacist, community'}},
#  {'first_name': 'Allen',
#   'last_name': 'Nelson',
#   'city': 'Carolineport',
#   'email': 'allen.nelson@gmail.com',
#   'occupation': {'company': 'Carroll Group',
#    'position': 'Community arts worker'}},
#  {'first_name': 'Denise',
#   'last_name': 'Sanders',
#   'city': 'Grahamtown',
#   'email': 'denise.sanders@yahoo.com',
#   'occupation': {'company': 'Salas-Ruiz',
#    'position': 'Information systems manager'}},
#  {'first_name': 'Kristen',
#   'last_name': 'Reyes',
#   'city': 'Lopezland',
#   'email': 'kristen.reyes@gmail.com',
#   'occupation': {'company': 'Alvarado-Davis', 'position': 'Patent examiner'}},
#  {'first_name': 'Sara',
#   'last_name': 'Nelson',
#   'city': 'Weissfurt',
#   'email': 'sara.nelson@hotmail.com',
# ...

# %% [markdown]
# #### Warm Up
# Write a function that takes in a name (first or last) and returns the position and company name of that person. If the user is not found, return -1

# %%
# Example 1
# get_person_info('Adam')
# Output: 'Records manager at Odom, Harper, and Allen'

# Example 2
# get_person_info('Burns')
# Output: 'Applications developer at Sanders-Ryan'

# Example 3
# get_person_info('Alice')
# Output: -1

# %%
data = [
    {
        'first_name': 'Adam',
        'last_name': 'Simpson',
        'city': 'West Maureenland',
        'email': 'adam.simpson@paul-williams.com',
        'occupation': {
            'company': 'Odom, Harper and Allen',
            'position': 'Records manager'
        }
    },
    {
        'first_name': 'Robert',
        'last_name': 'Miller',
        'city': 'South Jaredburgh',
        'email': 'robert.miller@allen.org',
        'occupation': {
            'company': 'Roberts-Jackson',
            'position': 'Media planner'
        }
    },
    {
        'first_name': 'Edwin',
        'last_name': 'Johnson',
        'city': 'Lake Kimberly',
        'email': 'edwin.johnson@sanders.biz',
        'occupation': {
            'company': 'Hart, Jones and Malone',
            'position': 'Therapist, speech and language'
        }
    },
    {
        'first_name': 'Gail',
        'last_name': 'Castro',
        'city': 'Brianchester',
        'email': 'gail.castro@suarez-sullivan.org',
        'occupation': {
            'company': 'Duncan-Gallagher',
            'position': 'Designer, multimedia'
        }
    },
    {
        'first_name': 'Andre',
        'last_name': 'Burns',
        'city': 'New Samuelside',
        'email': 'andre.burns@love.com',
        'occupation': {
            'company': 'Sanders-Ryan',
            'position': 'Applications developer'
        }
    },
    {
        'first_name': 'Nicole',
        'last_name': 'Maynard',
        'city': 'Teresaville',
        'email': 'nicole.maynard@chavez.com',
        'occupation': {
            'company': 'Hoffman, Reynolds and Wilson',
            'position': 'Community education officer'
        }
    },
    {
        'first_name': 'Megan',
        'last_name': 'Mcdonald',
        'city': 'Walkerfurt',
        'email': 'megan.mcdonald@guzman.info',
        'occupation': {
            'company': 'King Ltd',
            'position': 'Doctor, general practice'
        }
    },
    {
        'first_name': 'Stephen',
        'last_name': 'Young',
        'city': 'South Jeffrey',
        'email': 'stephen.young@smith.biz',
        'occupation': {
            'company': 'Hernandez LLC',
            'position': 'Environmental manager'
        }
    },
    {
        'first_name': 'Daniel',
        'last_name': 'Deleon',
        'city': 'Yatesburgh',
        'email': 'daniel.deleon@mcmahon.org',
        'occupation': {
            'company': 'Nelson-Wilson',
            'position': 'Sports development officer'
        }
    },
    {
        'first_name': 'Patricia',
        'last_name': 'Pacheco',
        'city': 'South Donnamouth',
        'email': 'patricia.pacheco@lee-wilson.com',
        'occupation': {
            'company': 'Giles, Williams and Jones',
            'position': 'Theatre manager'
        }
    }
]

def get_person_info(name):
    for person in data:
        if person['first_name'] == name or person['last_name'] == name:
            print(person['occupation'])
            return f"{person['occupation']['position']} at {person['occupation']['company']}"
    return -1
    
get_person_info('Young')
# Out:
# {'company': 'Hernandez LLC', 'position': 'Environmental manager'}
# 'Environmental manager at Hernandez LLC'

# %% [markdown]
# ### Requests Package
# <a href='https://docs.python-requests.org/en/latest/'>Docs</a>

# %% [markdown]
# #### Install and import package

# %%
# !python -m pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
print(requests)
# Out:
# <module 'requests' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\requests\\__init__.py'>

# %% [markdown]
# #### requests get method

# %%
help(requests.get)
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
response = requests.get('https://www.codingtemple.com/')

response
# Out:
# <Response [200]>

# %%
bad_response = requests.get('https://github.com/aosfdoiasjdof')

bad_response
# Out:
# <Response [404]>

# %% [markdown]
# #### Response object

# %%
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %%
help(response)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
response.status_code
# Out:
# 200

# %%
response.ok
# Out:
# True

# %%
bad_response.ok
# Out:
# False

# %% [markdown]
# #### .content

# %%
# response.content

# %% [markdown]
# #### .text

# %%
# print(response.text)

# %%
type(response.text)
# Out:
# str

# %% [markdown]
# #### JSON Response

# %%
poke_res = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')

poke_res
# Out:
# <Response [200]>

# %%
poke_res.ok
print(type(poke_res.text))
# Out:
# <class 'str'>

# %%
help(poke_res)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
data = poke_res.json()
data
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 25,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 25,
# ...

# %%
type(data)
# Out:
# dict

# %%
data.get('abilities')
# Out:
# [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'lightning-rod',
#    'url': 'https://pokeapi.co/api/v2/ability/31/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
data['abilities'][1]['ability']['name']
# Out:
# 'lightning-rod'

# %% [markdown]
# ### Python Wrappers

# %%
# http://api.weatherapi.com

# %%
base_url = "https://api.weatherapi.com/v1"
api_method = "/current.json"
api_key = "edb338f49422445f923203142230103"
city = "Los_Angeles"

api_url = f"{base_url}{api_method}?key={api_key}&q={city}"

print(api_url)
# Out:
# https://api.weatherapi.com/v1/current.json?key=edb338f49422445f923203142230103&q=Los_Angeles

# %%
res = requests.get(api_url)
weather_data = res.json()
weather_data
# Out:
# {'location': {'name': 'Los Angeles',
#   'region': 'California',
#   'country': 'United States of America',
#   'lat': 34.05,
#   'lon': -118.24,
#   'tz_id': 'America/Los_Angeles',
#   'localtime_epoch': 1677704066,
#   'localtime': '2023-03-01 12:54'},
#  'current': {'last_updated_epoch': 1677703500,
#   'last_updated': '2023-03-01 12:45',
#   'temp_c': 12.0,
#   'temp_f': 53.6,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 15.0,
#   'wind_kph': 24.1,
#   'wind_degree': 240,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1006.0,
#   'pressure_in': 29.72,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 32,
#   'cloud': 75,
#   'feelslike_c': 9.2,
#   'feelslike_f': 48.6,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 3.0,
#   'gust_mph': 21.3,
#   'gust_kph': 34.2}}

# %%
current_temp = weather_data['current']['temp_f']
print(current_temp)

feels_like = weather_data['current']['feelslike_f']
print(feels_like)

current_conditon = weather_data['current']['condition']['text']
print(current_conditon)
# Out:
# 53.6
# 48.6
# Partly cloudy

# %%
class CityWeather:
    def __init__(self, name, region, current, feels_like, condition):
        self.city = name
        self.region = region
        self.current_temp = current
        self.feels_like = feels_like
        self.condition = condition
        
    def __repr__(self):
        return f"<CityWeather|{self.city}>"
    
    def __str__(self):
        return f"It is currently {self.condition} and {self.current_temp} in {self.city}, {self.region}. \
It feels like {self.feels_like}"

# %%
c1 = CityWeather('Chicago', 'Illinois', 59.0, 58.5, 'Sunny')
print(c1)
c1
# Out:
# It is currently Sunny and 59.0 in Chicago, Illinois. It feels like 58.5
# <CityWeather|Chicago>

# %%
class WeatherAPI:
    base_url = "http://api.weatherapi.com/v1"
    
    def __init__(self, api_key):
        self.api_key = api_key
        
    def __get(self, city, api_method, **params): # Private method - can only be called from other methods within the class
        request_url = f"{self.base_url}{api_method}?key={self.api_key}&q={city}"
        if params:
            for key, value in params.items():
                request_url += f"&{key}={value}"
        weather_response = requests.get(request_url)
        if weather_response.ok:
            return weather_response.json()
        else:
            print('There was an error!')
    
    def get_current_weather(self, city):
        weather_data = self.__get(city, '/current.json')
        if weather_data:
            city_name = weather_data['location']['name']
            region = weather_data['location']['region']
            current_temp = weather_data['current']['temp_f']
            feels_like = weather_data['current']['feelslike_f']
            current_condition = weather_data['current']['condition']['text']
            city_weather = CityWeather(city_name, region, current_temp, feels_like, current_condition)
            return city_weather
        
    def get_forcast_weather(self,city, days=1):
        weather_data = self.__get(city, '/forcast.json', days=days)
        return weather_data

# %%
client.get_current_weather('Lake Forest')
# Out:
# <CityWeather|Lake Forest>

# %%
client.get_current_weather('Denver')
# Out:
# <CityWeather|Denver>

# %%
san_fran = client.get_current_weather('San Francisco')
print(san_fran)
# Out:
# It is currently Sunny and 50.0 in San Francisco, California. It feels like 44.5

# %%
san_fran.current_temp
# Out:
# 50.0

# %%
client.get_forcast_weather('Chicago', 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15716\3365688350.py in <module>
# ----> 1 client.get_forcast_weather('Chicago', 3)
#
# AttributeError: 'WeatherAPI' object has no attribute 'get_forcast_weather'

# %%
def run():
    api_key = input('Please enter your API key: ')
    client = WeatherAPI(api_key)
    city = input('Which city? ')
    while city != 'quit':
        city_info = client.get_current_weather(city)
        print(city_info)
        city = input('Please enter another city: ')
        
run()
# Out:
# Please enter your API key: edb338f49422445f923203142230103
# Which city? Lake Forest
# It is currently Partly cloudy and 55.0 in Lake Forest, California. It feels like 49.1
# Please enter another city: Denver
# It is currently Overcast and 33.8 in Denver, Colorado. It feels like 32.5
# Please enter another city: Blue Ridge
# It is currently Partly cloudy and 75.2 in Blue Ridge, Mara. It feels like 79.9
# Please enter another city: Blue Ridge, Georgia
# It is currently Partly cloudy and 75.2 in Blue Ridge, Mara. It feels like 79.9
# Please enter another city: Blue Ridge Georgia
# It is currently Partly cloudy and 75.2 in Blue Ridge, Mara. It feels like 79.9
# Please enter another city: quit

# %% [markdown]
# # Exercise

# %% [markdown]
# #### Pokemon API Wrapper

# %% [markdown]
# Create a python wrapper for the Pokemon API. It should take in a pokemon name and display the pokemon with its height and weight

# %%
base_url = "https://pokeapi.co/api/v2/pokemon"
name = "Pikachu"

api_url = f"{base_url}/{name.lower()}"

print(api_url)

# https://pokeapi.co/api/v2/pokemon/pikachu
# Out:
# https://pokeapi.co/api/v2/pokemon/pikachu

# %%
res = requests.get(api_url)
pokemon_data = res.json()
# pokemon_data
import requests

class PokemonAPI:
    base_url = "https://pokeapi.co/api/v2"
    
    def __init__(self, name):
        self.name = name
    
    def __get(self, endpoint, **params):
        endpoint = endpoint.lower()  # Convert endpoint to lowercase
        request_url = f"{self.base_url}/{endpoint}"
        response = requests.get(request_url, params=params)
        if response.ok:
            return response.json()
        else:
            print('There was an error!')
    
    def get_pokemon_info(self):
        # Retrieve data for the specified Pokemon
        response = self.__get(f"pokemon/{self.name}")
        
        # Extract the name and return it
        print(f"{response['name'].title()} is {response['height']} feet tall and weighs {response['weight']} pounds.")

client1 = PokemonAPI('pikachu')
client1.get_pokemon_info()
# Out:
# Pikachu is 4 feet tall and weighs 60 pounds.
